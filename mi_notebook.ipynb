# %%
print("Hola Mica")
# Out:
# Hola Mica

# %%
import pandas as pd
import numpy as np

# %%
df_crudo = pd.read_csv("./data/credit_scores.csv", sep=";")

# %%
df = df_crudo.drop('xml_response', axis=1)

# %%
df.head(2)
# Out:
#         id  score                     name sex  user_id  \
# 0  3678359    120  SANTILLAN FACUNDO ARIEL   M  4053914
# 1  3678358    710    VALLBONA DAIANA LAURA   F  4053904
#
#                 created_at               updated_at  accepted modelo_score  \
# 0  2025-09-04 02:11:07.953  2025-09-04 02:11:07.973      True            H
# 1  2025-09-04 02:11:02.084  2025-09-04 02:11:02.111      True            H
#
#                                            domicilio  ...  last_name  \
# 0                GABOTO 1014 MERLO 1722 BUENOS AIRES  ...  SANTILLAN
# 1  ALCORTA 3653 MATANZA BUENOS AIRES TINOGASTA 17...  ...   VALLBONA
#
#            cuil    work_type third_party_committed_amount  \
# 0  2.044353e+10  Desempleado                          0.0
# 1  2.737989e+10  Desempleado                       1437.5
#
#   third_party_total_loans_amount post_code  lock_version sueldo_bruto  \
# 0                              0    1722.0             1       692000
# ...

# %%
df.tail(2)
# Out:
#           id  score                        name sex  user_id  \
# 998  3677318    670  RODRIGUEZ ROCIO MARIANELLA   F  4052676
# 999  3677317    461    CHIAPPERO MARIA VICTORIA   F  4052678
#
#                   created_at               updated_at  accepted modelo_score  \
# 998  2025-09-03 23:34:39.908  2025-09-03 23:34:39.920      True            H
# 999  2025-09-03 23:34:31.822  2025-09-03 23:34:31.880      True            H
#
#                                              domicilio  ...  last_name  \
# 998                  BO COVIRPOL 1-9 LAS HERAS MENDOZA  ...  RODRIGUEZ
# 999  UNO 2865 FRONTERA 2438 SANTA FE LARREA 353 SAN...  ...  CHIAPPERO
#
#              cuil                work_type third_party_committed_amount  \
# 998  2.735077e+10           Monotributista                         0.00
# 999  2.733618e+10  Relación de dependencia                    127708.33
#
#     third_party_total_loans_amount post_code  lock_version sueldo_bruto  \
# ...

# %%
# Describe la tabla medidas básicas estadísticas
df.describe()
# Out:
#                  id        score       user_id  empleadores  bcra_cheques  \
# count  1.000000e+03  1000.000000  1.000000e+03          0.0   1000.000000
# mean   3.677838e+06   459.911000  4.051129e+06          NaN      0.004000
# std    3.028732e+02   339.552899  2.891160e+04          NaN      0.126491
# min    3.677317e+06     1.000000  3.522182e+06          NaN      0.000000
# 25%    3.677574e+06    96.000000  4.052961e+06          NaN      0.000000
# 50%    3.677842e+06   532.500000  4.053268e+06          NaN      0.000000
# 75%    3.678100e+06   778.000000  4.053588e+06          NaN      0.000000
# max    3.678359e+06   996.000000  4.053914e+06          NaN      4.000000
#
#        fraudes  creditos_vigentes  creditos_cancelados    ses_level  \
# count      0.0                0.0                  0.0  1000.000000
# mean       NaN                NaN                  NaN     8.295000
# std        NaN                NaN                  NaN     1.881892
# ...

# %%
df.dtypes
# Out:
# id                                  int64
# score                               int64
# name                               object
# sex                                object
# user_id                             int64
# created_at                         object
# updated_at                         object
# accepted                             bool
# modelo_score                       object
# domicilio                          object
# telefonos                          object
# familiares                         object
# empleadores                       float64
# laborales                          object
# morosidades                        object
# morosidades_historicas             object
# bcra_cheques                        int64
# modelos_ses                        object
# fraudes                           float64
# creditos_vigentes                 float64
# creditos_cancelados               float64
# ses_level                           int64
# ...

# %%
# Traer 5 filas aleatorias
df.sample(5)
# Out:
#           id  score                     name sex  user_id  \
# 701  3677623     47    MUÃOZ ANGELES ORIANA   F  4053030
# 777  3677543    382     GIORDA LUCAS RODRIGO   M  4052937
# 409  3677935    769  GONZALEZ ROCIO AGUSTINA   F  4053401
# 745  3677578    665         CAVALIERE MICKEY   M  4052981
# 635  3677697    703   RAMIRA FACUNDO NICOLAS   M  4053117
#
#                   created_at               updated_at  accepted modelo_score  \
# 701  2025-09-04 00:19:21.267  2025-09-04 00:19:21.291      True            H
# 777  2025-09-04 00:08:05.410  2025-09-04 00:08:05.426      True            H
# 409  2025-09-04 01:04:14.455  2025-09-04 01:04:14.468      True            H
# 745  2025-09-04 00:11:53.951  2025-09-04 00:11:53.968      True            H
# 635  2025-09-04 00:28:27.487  2025-09-04 00:28:27.511      True            H
#
#                                              domicilio  ...  last_name  \
# 701             MARTIN DE LOYOLA 409 San Luis SAN LUIS  ...     MUÃOZ
# ...

# %%
# Q filas y columnas tiene el DataFrame
df.shape
# Out:
# (1000, 38)

# %%
scores = df['score']

# %%
# Estadisticas básicas de la columna score
scores.describe()
# Out:
# count    1000.000000
# mean      459.911000
# std       339.552899
# min         1.000000
# 25%        96.000000
# 50%       532.500000
# 75%       778.000000
# max       996.000000
# Name: score, dtype: float64
